# %% [markdown]
# # Import and Clean Data

# %% [markdown]
# Import Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns

plt.style.use('seaborn')
# %matplotlib inline

# %% [markdown]
# Read in data

# %%
movies = pd.read_csv('movies.csv')
movies.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %% [markdown]
# Look for missing data

# %%
for col in movies.columns:
    pct_missing = np.mean(movies[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5421 entries, 0 to 5420
# Data columns (total 15 columns):
# name        5421 non-null object
# rating      5421 non-null object
# genre       5421 non-null object
# year        5421 non-null int64
# released    5421 non-null object
# score       5421 non-null float64
# votes       5421 non-null int64
# director    5421 non-null object
# writer      5421 non-null object
# star        5421 non-null object
# country     5421 non-null object
# budget      5421 non-null int64
# gross       5421 non-null int64
# company     5421 non-null object
# runtime     5421 non-null int64
# dtypes: float64(1), int64(5), object(9)
# memory usage: 635.4+ KB

# %% [markdown]
# Check data types for columns

# %%
movies.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes         int64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime       int64
# dtype: object

# %% [markdown]
# Change data type of columns

# %%
movies['budget'] = movies['budget'].astype('int64')
movies['gross'] = movies['gross'].astype('int64')

# %% [markdown]
# Order by gross revenue

# %%
movies.sort_values(by='gross', inplace=False, ascending=False)
# Out:
#                                             name     rating   genre  year  \
# 3731                                      Avatar      PG-13  Action  2009
# 5302                           Avengers: Endgame      PG-13  Action  2019
# 1795                                     Titanic      PG-13   Drama  1997
# 4730  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 5158                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 3898                                 Tanner Hall          R   Drama  2009
# 1378                  Philadelphia Experiment II      PG-13  Action  1993
# 2286                                Ginger Snaps  Not Rated   Drama  2000
# 154                                     Parasite          R  Horror  1982
# 1920                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score    votes             director  \
# ...

# %% [markdown]
# Drop duplicates

# %%
movies.drop_duplicates()
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 5416                               Bad Boys for Life          R     Action
# 5417                              Sonic the Hedgehog         PG     Action
# 5418                                        Dolittle         PG  Adventure
# 5419                            The Call of the Wild         PG  Adventure
# 5420                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score    votes  \
# ...

# %% [markdown]
# # Look Correlations with gross

# %% [markdown]
# Scatter plot of budget vs gross

# %%
plt.figure(figsize=(20,10))
plt.scatter(x=movies['budget']/1000000, y=movies['gross']/1000000, color='red')
plt.title('Budget vs Gross')
plt.xlabel('Budget ($1,000,000s)')
plt.ylabel('Gross ($1,000,000)')
plt.show()

# %% [markdown]
# Plot budget vs gross in seaborn

# %%
plt.figure(figsize=(20,10))
sns.regplot(x=movies['budget']/1000000, y=movies['gross']/1000000, data=movies, scatter_kws={'color':'red'}, line_kws={'color':'blue'})
plt.title('Budget vs Gross')
plt.xlabel('Budget ($1,000,000s)')
plt.ylabel('Gross ($1,000,000)')
# Out:
# Text(0, 0.5, 'Gross ($1,000,000)')

# %% [markdown]
# Checking Numeric Field Correlations

# %%
movies.corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
plt.figure(figsize=(20,10))
corr_matrix = movies.corr()
ax = sns.heatmap(corr_matrix, annot=True)
plt.title('Correlation Matrix (Numeric Features)')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %% [markdown]
# Look at Company

# %%
movies_categorized = movies
movies_categorized.drop(['released'], axis=1, inplace=True)
for col in movies_categorized.columns:
    if(movies_categorized[col].dtype == 'object'):
        movies_categorized[col] = movies_categorized[col].astype('category')
        movies_categorized[col] = movies_categorized[col].cat.codes
movies_categorized
# Out:
#       name  rating  genre  year  score    votes  director  writer  star  \
# 0     4692       6      6  1980    8.4   927000      1795    2832   699
# 1     3929       6      1  1980    5.8    65000      1578    1158   214
# 2     3641       4      0  1980    8.7  1200000       757    1818  1157
# 3      204       4      4  1980    7.7   221000       889    1413  1474
# 4      732       6      4  1980    7.3   108000       719     351   271
# ...    ...     ...    ...   ...    ...      ...       ...     ...   ...
# 5416   415       6      0  2020    6.6   140000        16    2390  1812
# 5417  3556       4      0  2020    6.5   102000       852    2309   147
# 5418  1153       4      1  2020    5.6    53000      1809    2827  1470
# 5419  3978       4      1  2020    6.8    42000       294    2091   640
# 5420  4090       3      0  2020    6.8     3700       746    1184  1839
#
#       country     budget      gross  company  runtime
# ...

# %%
plt.figure(figsize=(20,10))
corr_matrix = movies_categorized.corr()
ax = sns.heatmap(corr_matrix, annot=True)
plt.title('Correlation Matrix (All Features)')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %%
movies_categorized.corr()
# Out:
#               name    rating     genre      year     score     votes  \
# name      1.000000 -0.029234  0.010996  0.025542  0.014450  0.012615
# rating   -0.029234  1.000000  0.147796  0.019499  0.065983  0.006031
# genre     0.010996  0.147796  1.000000 -0.073167  0.035106 -0.135990
# year      0.025542  0.019499 -0.073167  1.000000  0.056386  0.206021
# score     0.014450  0.065983  0.035106  0.056386  1.000000  0.474256
# votes     0.012615  0.006031 -0.135990  0.206021  0.474256  1.000000
# director  0.015246  0.014656 -0.008553 -0.038354  0.005413 -0.010376
# writer    0.012880 -0.003149  0.017578 -0.025908  0.012843 -0.005316
# star     -0.006882  0.009196  0.003341 -0.032157  0.007296 -0.017638
# country  -0.025490  0.008230 -0.009164 -0.066748 -0.043051  0.041551
# budget    0.023392 -0.203946 -0.368523  0.327722  0.072001  0.439675
# gross     0.005639 -0.181906 -0.244101  0.274321  0.222556  0.614751
# company   0.021697 -0.092357 -0.071334 -0.014333  0.020656  0.118470
# ...

# %%
corr_matrix = movies_categorized.corr()

corr_pairs = corr_matrix.unstack()
corr_pairs
# Out:
# name     name       1.000000
#          rating    -0.029234
#          genre      0.010996
#          year       0.025542
#          score      0.014450
#                       ...
# runtime  country   -0.034477
#          budget     0.318695
#          gross      0.275796
#          company    0.037585
#          runtime    1.000000
# Length: 196, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# genre    budget    -0.368523
# budget   genre     -0.368523
# gross    genre     -0.244101
# genre    gross     -0.244101
# budget   rating    -0.203946
#                       ...
# year     year       1.000000
# genre    genre      1.000000
# rating   rating     1.000000
# company  company    1.000000
# runtime  runtime    1.000000
# Length: 196, dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs > 0.5) & (sorted_pairs < 1)]
high_corr
# Out:
# gross   votes     0.614751
# votes   gross     0.614751
# budget  gross     0.740247
# gross   budget    0.740247
# dtype: float64

# %% [markdown]
# Votes and budget have the highest correlation to gross
